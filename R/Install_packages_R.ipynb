# %% [markdown]
# # Instalace knihovny pro programovací jazyk R

# %%
 install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/lib64/R/library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘prettyunits’, ‘rprojroot’, ‘pkgbuild’, ‘rstudioapi’, ‘diffobj’, ‘rematch2’, ‘brio’, ‘callr’, ‘desc’, ‘pkgload’, ‘praise’, ‘processx’, ‘ps’, ‘waldo’, ‘colorspace’, ‘testthat’, ‘farver’, ‘labeling’, ‘munsell’, ‘R6’, ‘RColorBrewer’, ‘viridisLite’, ‘magrittr’, ‘pkgconfig’, ‘gtable’, ‘isoband’, ‘scales’, ‘tibble’, ‘withr’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %% [markdown]
# Po spuštění předchozího příkazu je nutné počkat, až je celá operace dokončena

# %% [markdown]
# ## Načtení knihovny

# %%
require("ggplot2")
# Out:
# Loading required package: ggplot2

# %% [markdown]
# ## Zobrazení nápovědy k nově nainstalované knihovně

# %%
help("ggplot2")

# %% [markdown]
# ## Ukázka použití příkazu `qplot` z načtené knihovny

# %%
library(ggplot2)
 
qplot(wt,
      mpg,
      data = mtcars)
# Out:
# plot without title
